# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Recall, Precision, MeanIoU

from tensorflow.keras import backend as K
import time
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
np.random.seed(42)
tf.random.set_seed(42)

IMAGE_SIZE = 128
EPOCHS = 70
BATCH = 8

# PATH = "/kaggle/input/chaos-tr-val-te/CHAOS_tr_val_te"




def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x


def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_image(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    y.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    return dataset


train_x_folder_path = "/kaggle/input/3dircadb-liver-tr-va-te/3DIRCADb_tr_va_te/train/CT_Images_HU_Clipped"
train_x_file_names = os.listdir(train_x_folder_path)
train_x = [os.path.join(train_x_folder_path, file_name) for file_name in train_x_file_names]
# train_x

train_y_folder_path = "/kaggle/input/3dircadb-liver-tr-va-te/3DIRCADb_tr_va_te/train/liver_masks"
train_y_file_names = os.listdir(train_y_folder_path)
train_y = [os.path.join(train_y_folder_path, file_name) for file_name in train_y_file_names]
# train_y




valid_x_folder_path = "/kaggle/input/3dircadb-liver-tr-va-te/3DIRCADb_tr_va_te/val/CT_Images_HU_Clipped"
valid_x_file_names = os.listdir(valid_x_folder_path)
valid_x = [os.path.join(valid_x_folder_path, file_name) for file_name in valid_x_file_names]
# valid_x

valid_y_folder_path = "/kaggle/input/3dircadb-liver-tr-va-te/3DIRCADb_tr_va_te/val/liver_masks"
valid_y_file_names = os.listdir(valid_y_folder_path)
valid_y = [os.path.join(valid_y_folder_path, file_name) for file_name in valid_y_file_names]
# valid_y


test_x_folder_path = "/kaggle/input/3dircadb-liver-tr-va-te/3DIRCADb_tr_va_te/test/CT_Images_HU_Clipped"
test_x_file_names = os.listdir(test_x_folder_path)
test_x = [os.path.join(test_x_folder_path, file_name) for file_name in test_x_file_names]
# test_x

test_y_folder_path = "/kaggle/input/3dircadb-liver-tr-va-te/3DIRCADb_tr_va_te/test/liver_masks"
test_y_file_names = os.listdir(test_y_folder_path)
test_y = [os.path.join(test_y_folder_path, file_name) for file_name in test_y_file_names]
# test_y

print("Train_X")
print("Training data: ", len(train_x))
print("Validation data: ", len(valid_x))
print("Testing data: ", len(test_x))

print("Train_Y")
print("Training data: ", len(train_y))
print("Validation data: ", len(valid_y))
print("Testing data: ", len(test_y))
# Out:
# Train_X
# Training data:  1976
# Validation data:  282
# Testing data:  565
# Train_Y
# Training data:  1976
# Validation data:  282
# Testing data:  565

# %%
def read_and_rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x


fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_x[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_x[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_x[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_x[3]))
imgplot.set_clim(0.0, 2.1)

fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_y[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_y[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_y[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_y[3]))
imgplot.set_clim(0.0, 1.4)

# %%
from tensorflow import keras
# !pip install keras-unet-collection



from keras_unet_collection import models, utils

# the indicator of a fresh run
first_time_running = False
# Out:
# Collecting keras-unet-collection
#   Downloading keras_unet_collection-0.1.13-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: keras-unet-collection
# Successfully installed keras-unet-collection-0.1.13

# %%
train_dataset = tf_dataset(train_x, train_y, batch=BATCH)
valid_dataset = tf_dataset(valid_x, valid_y, batch=BATCH)

train_steps = len(train_x)//BATCH
valid_steps = len(valid_x)//BATCH

if len(train_x) % BATCH != 0:
    train_steps += 1
if len(valid_x) % BATCH != 0:
    valid_steps += 1


smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall


def f1_score(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    return 2 * ((p * r) / (p + r + K.epsilon()))

def accuracy(y_true, y_pred):
    return K.mean(K.equal(y_true, K.round(y_pred)))


def voe_metric(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    voe = 1.0 - (intersection / union)
    return voe

def rvd_metric(y_true, y_pred):
    volume_pred = tf.reduce_sum(y_pred)
    volume_gt = tf.reduce_sum(y_true)
    rvd = ((volume_pred - volume_gt) / volume_gt)
    return rvd

def iou(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    
    iou_score = intersection / (union + smooth)
    return iou_score

LR = 1e-4
opt = tf.keras.optimizers.legacy.Nadam(LR)
metrics = [dice_coef, recall, precision, f1_score, accuracy, iou, voe_metric, rvd_metric]

# %%
model = models.unet_3plus_2d((128, 128, 3), n_labels=3, filter_num_down=[64, 128, 256, 512], 
                             filter_num_skip='auto', filter_num_aggregate='auto', 
                             stack_num_down=2, stack_num_up=1, activation='ReLU', output_activation='Sigmoid',
                             batch_norm=True, pool='max', unpool=False, deep_supervision=False, name='unet3plus')


model.compile(loss=dice_loss, optimizer=opt, metrics=metrics)
model.summary()
# Out:
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of convolution filters after each full-scale skip connection: filter_num_skip = [64, 64, 64]
# 	Number of channels of full-scale aggregated feature maps: filter_num_aggregate = 256
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  unet3plus_down0_0 (Conv2D)     (None, 128, 128, 64  1728        ['input_1[0][0]']
#                                 )
#
#  unet3plus_down0_0_bn (BatchNor  (None, 128, 128, 64  256        ['unet3plus_down0_0[0][0]']
#  malization)                    )
#
#  unet3plus_down0_0_activation (  (None, 128, 128, 64  0          ['unet3plus_down0_0_bn[0][0]']
#  ReLU)                          )
#
#  unet3plus_down0_1 (Conv2D)     (None, 128, 128, 64  36864       ['unet3plus_down0_0_activation[0]
#                                 )                                [0]']
#
#  unet3plus_down0_1_bn (BatchNor  (None, 128, 128, 64  256        ['unet3plus_down0_1[0][0]']
#  malization)                    )
#
#  unet3plus_down0_1_activation (  (None, 128, 128, 64  0          ['unet3plus_down0_1_bn[0][0]']
#  ReLU)                          )
#
#  unet3plus_down1_encode_maxpool  (None, 64, 64, 64)  0           ['unet3plus_down0_1_activation[0]
#   (MaxPooling2D)                                                 [0]']
#
#  unet3plus_down1_conv_0 (Conv2D  (None, 64, 64, 128)  73728      ['unet3plus_down1_encode_maxpool[
#  )                                                               0][0]']
#
#  unet3plus_down1_conv_0_bn (Bat  (None, 64, 64, 128)  512        ['unet3plus_down1_conv_0[0][0]']
#  chNormalization)
#
#  unet3plus_down1_conv_0_activat  (None, 64, 64, 128)  0          ['unet3plus_down1_conv_0_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  unet3plus_down1_conv_1 (Conv2D  (None, 64, 64, 128)  147456     ['unet3plus_down1_conv_0_activati
#  )                                                               on[0][0]']
#
#  unet3plus_down1_conv_1_bn (Bat  (None, 64, 64, 128)  512        ['unet3plus_down1_conv_1[0][0]']
#  chNormalization)
#
#  unet3plus_down1_conv_1_activat  (None, 64, 64, 128)  0          ['unet3plus_down1_conv_1_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  unet3plus_down2_encode_maxpool  (None, 32, 32, 128)  0          ['unet3plus_down1_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  unet3plus_down2_conv_0 (Conv2D  (None, 32, 32, 256)  294912     ['unet3plus_down2_encode_maxpool[
#  )                                                               0][0]']
#
#  unet3plus_down2_conv_0_bn (Bat  (None, 32, 32, 256)  1024       ['unet3plus_down2_conv_0[0][0]']
#  chNormalization)
#
#  unet3plus_down2_conv_0_activat  (None, 32, 32, 256)  0          ['unet3plus_down2_conv_0_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  unet3plus_down2_conv_1 (Conv2D  (None, 32, 32, 256)  589824     ['unet3plus_down2_conv_0_activati
#  )                                                               on[0][0]']
#
#  unet3plus_down2_conv_1_bn (Bat  (None, 32, 32, 256)  1024       ['unet3plus_down2_conv_1[0][0]']
#  chNormalization)
#
#  unet3plus_down2_conv_1_activat  (None, 32, 32, 256)  0          ['unet3plus_down2_conv_1_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  unet3plus_down3_encode_maxpool  (None, 16, 16, 256)  0          ['unet3plus_down2_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  unet3plus_down3_conv_0 (Conv2D  (None, 16, 16, 512)  1179648    ['unet3plus_down3_encode_maxpool[
#  )                                                               0][0]']
#
#  unet3plus_down3_conv_0_bn (Bat  (None, 16, 16, 512)  2048       ['unet3plus_down3_conv_0[0][0]']
#  chNormalization)
#
#  unet3plus_down3_conv_0_activat  (None, 16, 16, 512)  0          ['unet3plus_down3_conv_0_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  unet3plus_down3_conv_1 (Conv2D  (None, 16, 16, 512)  2359296    ['unet3plus_down3_conv_0_activati
#  )                                                               on[0][0]']
#
#  unet3plus_down3_conv_1_bn (Bat  (None, 16, 16, 512)  2048       ['unet3plus_down3_conv_1[0][0]']
#  chNormalization)
#
#  unet3plus_down3_conv_1_activat  (None, 16, 16, 512)  0          ['unet3plus_down3_conv_1_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  unet3plus_up_0_en0_trans_conv   (None, 32, 32, 64)  294976      ['unet3plus_down3_conv_1_activati
#  (Conv2DTranspose)                                               on[0][0]']
#
#  unet3plus_up_0_en0_bn (BatchNo  (None, 32, 32, 64)  256         ['unet3plus_up_0_en0_trans_conv[0
#  rmalization)                                                    ][0]']
#
#  unet3plus_up_0_en0_activation   (None, 32, 32, 64)  0           ['unet3plus_up_0_en0_bn[0][0]']
#  (ReLU)
#
#  unet3plus_down_0_en2_maxpool (  (None, 32, 32, 128)  0          ['unet3plus_down1_conv_1_activati
#  MaxPooling2D)                                                   on[0][0]']
#
#  unet3plus_down_from0_to0_0 (Co  (None, 32, 32, 64)  36864       ['unet3plus_up_0_en0_activation[0
#  nv2D)                                                           ][0]']
#
#  unet3plus_down_from0_to1_0 (Co  (None, 32, 32, 64)  147456      ['unet3plus_down2_conv_1_activati
#  nv2D)                                                           on[0][0]']
#
#  unet3plus_down_from0_to2_0 (Co  (None, 32, 32, 64)  73728       ['unet3plus_down_0_en2_maxpool[0]
#  nv2D)                                                           [0]']
#
#  unet3plus_down_from0_to0_0_bn   (None, 32, 32, 64)  256         ['unet3plus_down_from0_to0_0[0][0
#  (BatchNormalization)                                            ]']
#
#  unet3plus_down_from0_to1_0_bn   (None, 32, 32, 64)  256         ['unet3plus_down_from0_to1_0[0][0
#  (BatchNormalization)                                            ]']
#
#  unet3plus_down_from0_to2_0_bn   (None, 32, 32, 64)  256         ['unet3plus_down_from0_to2_0[0][0
#  (BatchNormalization)                                            ]']
#
#  unet3plus_down_from0_to0_0_act  (None, 32, 32, 64)  0           ['unet3plus_down_from0_to0_0_bn[0
#  ivation (ReLU)                                                  ][0]']
#
#  unet3plus_down_from0_to1_0_act  (None, 32, 32, 64)  0           ['unet3plus_down_from0_to1_0_bn[0
#  ivation (ReLU)                                                  ][0]']
#
#  unet3plus_down_from0_to2_0_act  (None, 32, 32, 64)  0           ['unet3plus_down_from0_to2_0_bn[0
#  ivation (ReLU)                                                  ][0]']
#
#  unet3plus_concat_0 (Concatenat  (None, 32, 32, 192)  0          ['unet3plus_down_from0_to0_0_acti
#  e)                                                              vation[0][0]',
#                                                                   'unet3plus_down_from0_to1_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from0_to2_0_acti
#                                                                  vation[0][0]']
#
#  unet3plus_fusion_conv_0_0 (Con  (None, 32, 32, 256)  442368     ['unet3plus_concat_0[0][0]']
#  v2D)
#
#  unet3plus_fusion_conv_0_0_bn (  (None, 32, 32, 256)  1024       ['unet3plus_fusion_conv_0_0[0][0]
#  BatchNormalization)                                             ']
#
#  unet3plus_fusion_conv_0_0_acti  (None, 32, 32, 256)  0          ['unet3plus_fusion_conv_0_0_bn[0]
#  vation (ReLU)                                                   [0]']
#
#  unet3plus_up_1_en0_trans_conv   (None, 64, 64, 64)  294976      ['unet3plus_down3_conv_1_activati
#  (Conv2DTranspose)                                               on[0][0]']
#
#  unet3plus_up_1_en1_trans_conv   (None, 64, 64, 64)  147520      ['unet3plus_fusion_conv_0_0_activ
#  (Conv2DTranspose)                                               ation[0][0]']
#
#  unet3plus_up_1_en0_bn (BatchNo  (None, 64, 64, 64)  256         ['unet3plus_up_1_en0_trans_conv[0
#  rmalization)                                                    ][0]']
#
#  unet3plus_up_1_en1_bn (BatchNo  (None, 64, 64, 64)  256         ['unet3plus_up_1_en1_trans_conv[0
#  rmalization)                                                    ][0]']
#
#  unet3plus_up_1_en0_activation   (None, 64, 64, 64)  0           ['unet3plus_up_1_en0_bn[0][0]']
#  (ReLU)
#
#  unet3plus_up_1_en1_activation   (None, 64, 64, 64)  0           ['unet3plus_up_1_en1_bn[0][0]']
#  (ReLU)
#
#  unet3plus_down_from1_to0_0 (Co  (None, 64, 64, 64)  36864       ['unet3plus_up_1_en0_activation[0
#  nv2D)                                                           ][0]']
#
#  unet3plus_down_from1_to1_0 (Co  (None, 64, 64, 64)  36864       ['unet3plus_up_1_en1_activation[0
#  nv2D)                                                           ][0]']
#
#  unet3plus_down_from1_to2_0 (Co  (None, 64, 64, 64)  73728       ['unet3plus_down1_conv_1_activati
#  nv2D)                                                           on[0][0]']
#
#  unet3plus_down_from1_to0_0_bn   (None, 64, 64, 64)  256         ['unet3plus_down_from1_to0_0[0][0
#  (BatchNormalization)                                            ]']
#
#  unet3plus_down_from1_to1_0_bn   (None, 64, 64, 64)  256         ['unet3plus_down_from1_to1_0[0][0
#  (BatchNormalization)                                            ]']
#
#  unet3plus_down_from1_to2_0_bn   (None, 64, 64, 64)  256         ['unet3plus_down_from1_to2_0[0][0
#  (BatchNormalization)                                            ]']
#
#  unet3plus_down_from1_to0_0_act  (None, 64, 64, 64)  0           ['unet3plus_down_from1_to0_0_bn[0
#  ivation (ReLU)                                                  ][0]']
#
#  unet3plus_down_from1_to1_0_act  (None, 64, 64, 64)  0           ['unet3plus_down_from1_to1_0_bn[0
#  ivation (ReLU)                                                  ][0]']
#
#  unet3plus_down_from1_to2_0_act  (None, 64, 64, 64)  0           ['unet3plus_down_from1_to2_0_bn[0
#  ivation (ReLU)                                                  ][0]']
#
#  unet3plus_concat_1 (Concatenat  (None, 64, 64, 192)  0          ['unet3plus_down_from1_to0_0_acti
#  e)                                                              vation[0][0]',
#                                                                   'unet3plus_down_from1_to1_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from1_to2_0_acti
#                                                                  vation[0][0]']
#
#  unet3plus_fusion_conv_1_0 (Con  (None, 64, 64, 256)  442368     ['unet3plus_concat_1[0][0]']
#  v2D)
#
#  unet3plus_fusion_conv_1_0_bn (  (None, 64, 64, 256)  1024       ['unet3plus_fusion_conv_1_0[0][0]
#  BatchNormalization)                                             ']
#
#  unet3plus_fusion_conv_1_0_acti  (None, 64, 64, 256)  0          ['unet3plus_fusion_conv_1_0_bn[0]
#  vation (ReLU)                                                   [0]']
#
#  unet3plus_up_2_en0_trans_conv   (None, 128, 128, 64  294976     ['unet3plus_down3_conv_1_activati
#  (Conv2DTranspose)              )                                on[0][0]']
#
#  unet3plus_up_2_en1_trans_conv   (None, 128, 128, 64  147520     ['unet3plus_fusion_conv_0_0_activ
#  (Conv2DTranspose)              )                                ation[0][0]']
#
#  unet3plus_up_2_en2_trans_conv   (None, 128, 128, 64  147520     ['unet3plus_fusion_conv_1_0_activ
#  (Conv2DTranspose)              )                                ation[0][0]']
#
#  unet3plus_up_2_en0_bn (BatchNo  (None, 128, 128, 64  256        ['unet3plus_up_2_en0_trans_conv[0
#  rmalization)                   )                                ][0]']
#
#  unet3plus_up_2_en1_bn (BatchNo  (None, 128, 128, 64  256        ['unet3plus_up_2_en1_trans_conv[0
#  rmalization)                   )                                ][0]']
#
#  unet3plus_up_2_en2_bn (BatchNo  (None, 128, 128, 64  256        ['unet3plus_up_2_en2_trans_conv[0
#  rmalization)                   )                                ][0]']
#
#  unet3plus_up_2_en0_activation   (None, 128, 128, 64  0          ['unet3plus_up_2_en0_bn[0][0]']
#  (ReLU)                         )
#
#  unet3plus_up_2_en1_activation   (None, 128, 128, 64  0          ['unet3plus_up_2_en1_bn[0][0]']
#  (ReLU)                         )
#
#  unet3plus_up_2_en2_activation   (None, 128, 128, 64  0          ['unet3plus_up_2_en2_bn[0][0]']
#  (ReLU)                         )
#
#  unet3plus_down_from2_to0_0 (Co  (None, 128, 128, 64  36864      ['unet3plus_up_2_en0_activation[0
#  nv2D)                          )                                ][0]']
#
#  unet3plus_down_from2_to1_0 (Co  (None, 128, 128, 64  36864      ['unet3plus_up_2_en1_activation[0
#  nv2D)                          )                                ][0]']
#
#  unet3plus_down_from2_to2_0 (Co  (None, 128, 128, 64  36864      ['unet3plus_up_2_en2_activation[0
#  nv2D)                          )                                ][0]']
#
#  unet3plus_down_from2_to0_0_bn   (None, 128, 128, 64  256        ['unet3plus_down_from2_to0_0[0][0
#  (BatchNormalization)           )                                ]']
#
#  unet3plus_down_from2_to1_0_bn   (None, 128, 128, 64  256        ['unet3plus_down_from2_to1_0[0][0
#  (BatchNormalization)           )                                ]']
#
#  unet3plus_down_from2_to2_0_bn   (None, 128, 128, 64  256        ['unet3plus_down_from2_to2_0[0][0
#  (BatchNormalization)           )                                ]']
#
#  unet3plus_down_from2_to0_0_act  (None, 128, 128, 64  0          ['unet3plus_down_from2_to0_0_bn[0
#  ivation (ReLU)                 )                                ][0]']
#
#  unet3plus_down_from2_to1_0_act  (None, 128, 128, 64  0          ['unet3plus_down_from2_to1_0_bn[0
#  ivation (ReLU)                 )                                ][0]']
#
#  unet3plus_down_from2_to2_0_act  (None, 128, 128, 64  0          ['unet3plus_down_from2_to2_0_bn[0
#  ivation (ReLU)                 )                                ][0]']
#
#  unet3plus_concat_2 (Concatenat  (None, 128, 128, 19  0          ['unet3plus_down_from2_to0_0_acti
#  e)                             2)                               vation[0][0]',
#                                                                   'unet3plus_down_from2_to1_0_acti
#                                                                  vation[0][0]',
#                                                                   'unet3plus_down_from2_to2_0_acti
#                                                                  vation[0][0]']
#
#  unet3plus_fusion_conv_2_0 (Con  (None, 128, 128, 25  442368     ['unet3plus_concat_2[0][0]']
#  v2D)                           6)
#
#  unet3plus_fusion_conv_2_0_bn (  (None, 128, 128, 25  1024       ['unet3plus_fusion_conv_2_0[0][0]
#  BatchNormalization)            6)                               ']
#
#  unet3plus_fusion_conv_2_0_acti  (None, 128, 128, 25  0          ['unet3plus_fusion_conv_2_0_bn[0]
#  vation (ReLU)                  6)                               [0]']
#
#  unet3plus_output_final (Conv2D  (None, 128, 128, 3)  6915       ['unet3plus_fusion_conv_2_0_activ
#  )                                                               ation[0][0]']
#
#  unet3plus_output_final_activat  (None, 128, 128, 3)  0          ['unet3plus_output_final[0][0]']
#  ion (Activation)
#
# ==================================================================================================
# Total params: 7,875,651
# Trainable params: 7,868,355
# Non-trainable params: 7,296
# __________________________________________________________________________________________________

# %%
import time

logdir='/kaggle/working/logs'
tensorboard_callback1 = tf.keras.callbacks.TensorBoard(log_dir=logdir)
tensorboard_callback2 = tf.keras.callbacks.EarlyStopping(min_delta=0.0010, patience=5, verbose=1, mode='min', start_from_epoch=0)


print("For U-Net 3+ 2D:")
start_time = time.time()
model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=[tensorboard_callback1, tensorboard_callback2]
)
end_time = time.time()
elapsed_time = end_time - start_time
print("Time taken to train the model: ", elapsed_time, "secs")
model.save('UNet3plus2D.hdf5')
# Out:
# For U-Net 3+ 2D:
# Epoch 1/70
# 247/247 [==============================] - 66s 196ms/step - loss: 0.3196 - dice_coef: 0.6804 - recall: 0.8471 - precision: 0.6614 - f1_score: 0.7079 - accuracy: 0.9553 - iou: 0.5531 - voe_metric: 0.4469 - rvd_metric: 4.9238 - val_loss: 0.9982 - val_dice_coef: 0.0018 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_accuracy: 0.9419 - val_iou: 8.9710e-04 - val_voe_metric: 0.9991 - val_rvd_metric: -0.9725
# Epoch 2/70
# 247/247 [==============================] - 30s 120ms/step - loss: 0.1927 - dice_coef: 0.8073 - recall: 0.8931 - precision: 0.7633 - f1_score: 0.8086 - accuracy: 0.9748 - iou: 0.6987 - voe_metric: 0.3013 - rvd_metric: 1.5456 - val_loss: 0.3115 - val_dice_coef: 0.6889 - val_recall: 0.6520 - val_precision: 0.7805 - val_f1_score: 0.6932 - val_accuracy: 0.9650 - val_iou: 0.5415 - val_voe_metric: 0.4585 - val_rvd_metric: -0.1369
# Epoch 3/70
# 247/247 [==============================] - 27s 110ms/step - loss: 0.1599 - dice_coef: 0.8401 - recall: 0.9032 - precision: 0.8094 - f1_score: 0.8407 - accuracy: 0.9754 - iou: 0.7442 - voe_metric: 0.2558 - rvd_metric: 1.3820 - val_loss: 0.1557 - val_dice_coef: 0.8450 - val_recall: 0.8582 - val_precision: 0.8462 - val_f1_score: 0.8446 - val_accuracy: 0.9760 - val_iou: 0.7378 - val_voe_metric: 0.2622 - val_rvd_metric: 0.0435
# Epoch 4/70
# 247/247 [==============================] - 27s 110ms/step - loss: 0.1241 - dice_coef: 0.8759 - recall: 0.9112 - precision: 0.8620 - f1_score: 0.8765 - accuracy: 0.9760 - iou: 0.7967 - voe_metric: 0.2033 - rvd_metric: 0.8864 - val_loss: 0.1198 - val_dice_coef: 0.8785 - val_recall: 0.8641 - val_precision: 0.9015 - val_f1_score: 0.8788 - val_accuracy: 0.9762 - val_iou: 0.7879 - val_voe_metric: 0.2121 - val_rvd_metric: -0.0282
# Epoch 5/70
# 247/247 [==============================] - 27s 109ms/step - loss: 0.0897 - dice_coef: 0.9103 - recall: 0.9355 - precision: 0.9009 - f1_score: 0.9110 - accuracy: 0.9769 - iou: 0.8511 - voe_metric: 0.1489 - rvd_metric: 0.9728 - val_loss: 0.0796 - val_dice_coef: 0.9208 - val_recall: 0.9201 - val_precision: 0.9279 - val_f1_score: 0.9214 - val_accuracy: 0.9780 - val_iou: 0.8576 - val_voe_metric: 0.1424 - val_rvd_metric: 0.0052
# Epoch 6/70
# 247/247 [==============================] - 27s 108ms/step - loss: 0.1057 - dice_coef: 0.8943 - recall: 0.9208 - precision: 0.8864 - f1_score: 0.8950 - accuracy: 0.9763 - iou: 0.8266 - voe_metric: 0.1734 - rvd_metric: 0.7182 - val_loss: 0.0690 - val_dice_coef: 0.9317 - val_recall: 0.9404 - val_precision: 0.9292 - val_f1_score: 0.9321 - val_accuracy: 0.9783 - val_iou: 0.8762 - val_voe_metric: 0.1238 - val_rvd_metric: 0.0257
# Epoch 7/70
# 247/247 [==============================] - 27s 110ms/step - loss: 0.0680 - dice_coef: 0.9320 - recall: 0.9513 - precision: 0.9235 - f1_score: 0.9328 - accuracy: 0.9777 - iou: 0.8858 - voe_metric: 0.1142 - rvd_metric: 0.3913 - val_loss: 0.0569 - val_dice_coef: 0.9436 - val_recall: 0.9511 - val_precision: 0.9406 - val_f1_score: 0.9439 - val_accuracy: 0.9787 - val_iou: 0.8962 - val_voe_metric: 0.1038 - val_rvd_metric: 0.0205
# Epoch 8/70
# 247/247 [==============================] - 27s 110ms/step - loss: 0.0851 - dice_coef: 0.9149 - recall: 0.9323 - precision: 0.9110 - f1_score: 0.9157 - accuracy: 0.9767 - iou: 0.8588 - voe_metric: 0.1412 - rvd_metric: 0.4780 - val_loss: 0.0550 - val_dice_coef: 0.9453 - val_recall: 0.9443 - val_precision: 0.9501 - val_f1_score: 0.9461 - val_accuracy: 0.9784 - val_iou: 0.8982 - val_voe_metric: 0.1018 - val_rvd_metric: -6.6966e-04
# Epoch 9/70
# 247/247 [==============================] - 27s 109ms/step - loss: 0.0621 - dice_coef: 0.9379 - recall: 0.9518 - precision: 0.9358 - f1_score: 0.9390 - accuracy: 0.9775 - iou: 0.8952 - voe_metric: 0.1048 - rvd_metric: 0.6852 - val_loss: 0.0688 - val_dice_coef: 0.9317 - val_recall: 0.8947 - val_precision: 0.9775 - val_f1_score: 0.9328 - val_accuracy: 0.9772 - val_iou: 0.8741 - val_voe_metric: 0.1259 - val_rvd_metric: -0.0841
# Epoch 10/70
# 247/247 [==============================] - 27s 109ms/step - loss: 0.0561 - dice_coef: 0.9439 - recall: 0.9525 - precision: 0.9428 - f1_score: 0.9452 - accuracy: 0.9778 - iou: 0.9037 - voe_metric: 0.0963 - rvd_metric: 0.1246 - val_loss: 0.0444 - val_dice_coef: 0.9555 - val_recall: 0.9319 - val_precision: 0.9833 - val_f1_score: 0.9567 - val_accuracy: 0.9785 - val_iou: 0.9150 - val_voe_metric: 0.0850 - val_rvd_metric: -0.0527
# Epoch 11/70
# 247/247 [==============================] - 27s 109ms/step - loss: 0.0808 - dice_coef: 0.9192 - recall: 0.9423 - precision: 0.9114 - f1_score: 0.9200 - accuracy: 0.9772 - iou: 0.8661 - voe_metric: 0.1339 - rvd_metric: 0.1176 - val_loss: 0.0477 - val_dice_coef: 0.9519 - val_recall: 0.9494 - val_precision: 0.9566 - val_f1_score: 0.9526 - val_accuracy: 0.9784 - val_iou: 0.9087 - val_voe_metric: 0.0913 - val_rvd_metric: -0.0058
# Epoch 12/70
# 247/247 [==============================] - 27s 109ms/step - loss: 0.0488 - dice_coef: 0.9512 - recall: 0.9537 - precision: 0.9529 - f1_score: 0.9525 - accuracy: 0.9779 - iou: 0.9123 - voe_metric: 0.0877 - rvd_metric: 0.0172 - val_loss: 0.0442 - val_dice_coef: 0.9558 - val_recall: 0.9386 - val_precision: 0.9756 - val_f1_score: 0.9564 - val_accuracy: 0.9784 - val_iou: 0.9155 - val_voe_metric: 0.0845 - val_rvd_metric: -0.0375
# Epoch 13/70
# 247/247 [==============================] - 27s 109ms/step - loss: 0.0398 - dice_coef: 0.9602 - recall: 0.9613 - precision: 0.9614 - f1_score: 0.9612 - accuracy: 0.9782 - iou: 0.9304 - voe_metric: 0.0696 - rvd_metric: 0.0037 - val_loss: 0.0322 - val_dice_coef: 0.9679 - val_recall: 0.9602 - val_precision: 0.9775 - val_f1_score: 0.9687 - val_accuracy: 0.9790 - val_iou: 0.9378 - val_voe_metric: 0.0622 - val_rvd_metric: -0.0173
# Epoch 14/70
# 247/247 [==============================] - 27s 110ms/step - loss: 0.0343 - dice_coef: 0.9657 - recall: 0.9672 - precision: 0.9668 - f1_score: 0.9669 - accuracy: 0.9784 - iou: 0.9391 - voe_metric: 0.0609 - rvd_metric: -0.0039 - val_loss: 0.0314 - val_dice_coef: 0.9687 - val_recall: 0.9596 - val_precision: 0.9800 - val_f1_score: 0.9696 - val_accuracy: 0.9790 - val_iou: 0.9393 - val_voe_metric: 0.0607 - val_rvd_metric: -0.0205
# Epoch 15/70
# 247/247 [==============================] - 27s 110ms/step - loss: 0.0323 - dice_coef: 0.9677 - recall: 0.9693 - precision: 0.9691 - f1_score: 0.9691 - accuracy: 0.9784 - iou: 0.9427 - voe_metric: 0.0573 - rvd_metric: 0.0017 - val_loss: 0.0286 - val_dice_coef: 0.9714 - val_recall: 0.9675 - val_precision: 0.9771 - val_f1_score: 0.9722 - val_accuracy: 0.9791 - val_iou: 0.9445 - val_voe_metric: 0.0555 - val_rvd_metric: -0.0095
# Epoch 16/70
# 247/247 [==============================] - 27s 110ms/step - loss: 0.0304 - dice_coef: 0.9696 - recall: 0.9710 - precision: 0.9714 - f1_score: 0.9711 - accuracy: 0.9784 - iou: 0.9462 - voe_metric: 0.0538 - rvd_metric: -0.0020 - val_loss: 0.0270 - val_dice_coef: 0.9730 - val_recall: 0.9750 - val_precision: 0.9728 - val_f1_score: 0.9739 - val_accuracy: 0.9791 - val_iou: 0.9475 - val_voe_metric: 0.0525 - val_rvd_metric: 0.0029
# Epoch 17/70
# 247/247 [==============================] - 27s 110ms/step - loss: 0.0290 - dice_coef: 0.9710 - recall: 0.9722 - precision: 0.9731 - f1_score: 0.9725 - accuracy: 0.9785 - iou: 0.9486 - voe_metric: 0.0514 - rvd_metric: -0.0047 - val_loss: 0.0264 - val_dice_coef: 0.9737 - val_recall: 0.9745 - val_precision: 0.9747 - val_f1_score: 0.9746 - val_accuracy: 0.9791 - val_iou: 0.9487 - val_voe_metric: 0.0513 - val_rvd_metric: 5.4890e-04
# Epoch 18/70
# 247/247 [==============================] - 27s 110ms/step - loss: 0.0331 - dice_coef: 0.9669 - recall: 0.9681 - precision: 0.9700 - f1_score: 0.9688 - accuracy: 0.9783 - iou: 0.9413 - voe_metric: 0.0587 - rvd_metric: 0.0035 - val_loss: 0.0922 - val_dice_coef: 0.9086 - val_recall: 0.8776 - val_precision: 0.9468 - val_f1_score: 0.9092 - val_accuracy: 0.9764 - val_iou: 0.8355 - val_voe_metric: 0.1645 - val_rvd_metric: -0.0686
# Epoch 19/70
# 247/247 [==============================] - 27s 109ms/step - loss: 0.0584 - dice_coef: 0.9416 - recall: 0.9493 - precision: 0.9449 - f1_score: 0.9430 - accuracy: 0.9774 - iou: 0.9010 - voe_metric: 0.0990 - rvd_metric: 0.1774 - val_loss: 0.0342 - val_dice_coef: 0.9658 - val_recall: 0.9699 - val_precision: 0.9632 - val_f1_score: 0.9665 - val_accuracy: 0.9788 - val_iou: 0.9340 - val_voe_metric: 0.0660 - val_rvd_metric: 0.0076
# Epoch 20/70
# 247/247 [==============================] - 27s 108ms/step - loss: 0.0450 - dice_coef: 0.9550 - recall: 0.9567 - precision: 0.9588 - f1_score: 0.9565 - accuracy: 0.9779 - iou: 0.9208 - voe_metric: 0.0792 - rvd_metric: 0.0066 - val_loss: 0.0288 - val_dice_coef: 0.9713 - val_recall: 0.9698 - val_precision: 0.9744 - val_f1_score: 0.9720 - val_accuracy: 0.9791 - val_iou: 0.9443 - val_voe_metric: 0.0557 - val_rvd_metric: -0.0042
# Epoch 21/70
# 247/247 [==============================] - 27s 110ms/step - loss: 0.0302 - dice_coef: 0.9698 - recall: 0.9712 - precision: 0.9722 - f1_score: 0.9717 - accuracy: 0.9784 - iou: 0.9465 - voe_metric: 0.0535 - rvd_metric: -0.0059 - val_loss: 0.0262 - val_dice_coef: 0.9738 - val_recall: 0.9711 - val_precision: 0.9785 - val_f1_score: 0.9747 - val_accuracy: 0.9791 - val_iou: 0.9491 - val_voe_metric: 0.0509 - val_rvd_metric: -0.0071
# Epoch 21: early stopping
# Time taken to train the model:  609.2678129673004 secs

# %%
test_dataset = tf_dataset(test_x, test_y, batch=BATCH)
test_steps = (len(test_x)//BATCH)
if len(test_x) % BATCH != 0:
    test_steps += 1


print("For U-Net 3+ 2D:")
model.evaluate(test_dataset, steps=test_steps)
# Out:
# For U-Net 3+ 2D:
# 71/71 [==============================] - 11s 160ms/step - loss: 0.0274 - dice_coef: 0.9725 - recall: 0.9694 - precision: 0.9779 - f1_score: 0.9736 - accuracy: 0.9771 - iou: 0.9466 - voe_metric: 0.0534 - rvd_metric: -0.0082
# [0.02744365856051445,
#  0.9725241661071777,
#  0.9693917036056519,
#  0.9778775572776794,
#  0.9735729694366455,
#  0.9770873188972473,
#  0.9466192722320557,
#  0.0533808171749115,
#  -0.008187665604054928]
